# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Loading The Database**

# %%
ta = pd.read_csv("hotel_bookings.csv")

# %% [markdown]
# # **Exploratory Data Analysis And Data Cleaning**

# %%
ta.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
ta.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
ta.shape
# Out:
# (119390, 32)

# %%
ta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
ta['reservation_status_date'] = pd.to_datetime(ta['reservation_status_date'], format='%d/%m/%Y')

# %%
ta.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
ta.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
ta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
ta.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
for col in ta.describe(include = 'object').columns:
    print(col)
    print(ta[col].unique())
    print('_'*75)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ___________________________________________________________________________
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ___________________________________________________________________________
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ___________________________________________________________________________
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
# ...

# %%
ta.drop(['company', 'agent'], axis = 1, inplace = True)
ta.dropna(inplace = True)

# %%
ta.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
ta.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
ta['adr'].plot(kind = 'box')
plt.savefig("Remove Outlier.jpg")

# %%
ta = ta[ta['adr']<5000]

# %%
ta.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# # **Data Analysis AND Data Visualization**

# %%
canceled_Percentage = ta['is_canceled'].value_counts(normalize = True)
canceled_Percentage
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6,5))
count = sns.countplot(data = ta, x = "is_canceled", hue = "is_canceled")
count.bar_label(count.containers[0])
count.bar_label(count.containers[1])
plt.legend(["not cancelled", "cancelled"])
plt.title("reservation_status_count", fontsize=20, fontweight='bold', pad=20)
plt.savefig("reservation_status_count.jpg")
plt.show()

# %%
plt.figure(figsize=(6,5))
count = sns.countplot(data = ta, x = "hotel", hue = "is_canceled", palette = {0:'#f0bc13', 1:'#14addb'})
count.bar_label(count.containers[0])
count.bar_label(count.containers[1])
plt.xlabel('Hotel')
plt.ylabel('Number of Reservation Status')
plt.legend(["not cancelled", "cancelled"])
plt.title("reservation status in Different Hotel", fontsize=20, fontweight='bold', pad=20)
plt.savefig("reservation status in Different Hotel.jpg")
plt.show()

# %%
resort_hotel = ta[ta["hotel"]=="Resort Hotel"]
resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %%
city_hotel = ta[ta["hotel"]=="City Hotel"]
city_hotel["is_canceled"].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.582918
# 1    0.417082
# Name: proportion, dtype: float64

# %%
resort_hotel = resort_hotel.groupby("reservation_status_date")[['adr']].mean()
resort_hotel
# Out:
#                                 adr
# reservation_status_date
# 2014-11-18                 0.000000
# 2015-01-01                61.966667
# 2015-01-02                 9.633750
# 2015-01-18                 0.000000
# 2015-01-21                37.301209
# ...                             ...
# 2017-09-08               101.012500
# 2017-09-09               147.778333
# 2017-09-10               145.272500
# 2017-09-12               153.570000
# 2017-09-14               105.930000
#
# [913 rows x 1 columns]

# %%
city_hotel = city_hotel.groupby("reservation_status_date")[['adr']].mean()
city_hotel
# Out:
#                                 adr
# reservation_status_date
# 2014-10-17                62.800000
# 2015-01-01                62.063158
# 2015-01-20                76.500000
# 2015-01-30                61.400000
# 2015-02-17                76.500000
# ...                             ...
# 2017-09-03               137.172600
# 2017-09-04               116.925385
# 2017-09-05               154.000000
# 2017-09-06                93.293333
# 2017-09-07               159.685000
#
# [864 rows x 1 columns]

# %%
plt.figure(figsize=(15,5))
plt.plot(resort_hotel.index, resort_hotel['adr'], label = 'Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label = 'City Hotel')
plt.legend(fontsize=15)
plt.title("Average Daily Rate in City And Resort Hotel", fontsize=20, fontweight='bold', pad=20)
plt.savefig("Average Daily Rate in City And Resort Hotel.jpg")
plt.show()

# %%
ta['month'] = ta['reservation_status_date'].dt.month
ta['month']
# Out:
# 0         7
# 1         7
# 2         7
# 3         7
# 4         7
#          ..
# 119385    9
# 119386    9
# 119387    9
# 119388    9
# 119389    9
# Name: month, Length: 118897, dtype: int32

# %%
plt.figure(figsize=(12,5))
sns.countplot(data = ta, x = 'month', hue = 'is_canceled', palette = {0:'#29c4a0', 1:'#944121'})
plt.xlabel('Month')
plt.ylabel('Number of Reservation')
plt.legend(["not cancelled", "cancelled"])
plt.title("Reservation Status Per Month", fontsize=20, fontweight='bold', pad=20)
plt.savefig("Reservation Status Per Month.jpg")
plt.show()

# %%
plt.figure(figsize=(12,5))
adr_month =  ta[ta['is_canceled']== 1].groupby('month')[['adr']].sum().reset_index()
sns.barplot(x='month',y='adr', data = adr_month,  palette='viridis')
plt.xlabel('Month')
plt.ylabel('Sum of ADR')
plt.title("ADR per Month", fontsize=20, fontweight='bold', pad=20)
plt.savefig("ADR per Month.jpg")
plt.show()

# %%
cancelled_data = ta[ta['is_canceled']==1]
top_10_country = cancelled_data['country'].value_counts()[:10]
top_10_country
# Out:
# country
# PRT    27514
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
# DEU     1218
# IRL      832
# BRA      830
# USA      501
# BEL      474
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,10))
color = ['#29c4a0', '#88de18', '#1d4f85', '#72996e','#14addb', '#f0bc13','#944121','pink','#1d4f85', '#fc1a0a']
plt.pie(top_10_country, autopct='%0.2f%%', labels = top_10_country.index, colors = color, startangle = 180, wedgeprops={'linewidth': .25, 'edgecolor': 'white'} )
plt.legend(loc=2)
plt.title("Top 10 country with reservation cancelled", fontsize=20, fontweight='bold', pad=20)
plt.savefig("Top 10 country with reservation cancelled.jpg")
plt.show()

# %%
ta['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
ta['market_segment'].value_counts(normalize = True)
# Out:
# market_segment
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: proportion, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize = True)
# Out:
# market_segment
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: proportion, dtype: float64

# %%
cancelled_ta_adr = cancelled_data.groupby('reservation_status_date') [['adr']].mean()
cancelled_ta_adr.reset_index(inplace=True)
cancelled_ta_adr.sort_values('reservation_status_date', inplace=True)
not_cancelled_data = ta[ta['is_canceled']==0]
not_cancelled_ta_adr = not_cancelled_data.groupby('reservation_status_date') [['adr']].mean()
not_cancelled_ta_adr.reset_index(inplace = True)
not_cancelled_ta_adr.sort_values('reservation_status_date', inplace = True)
plt.figure(figsize = (20,6))
plt.plot(not_cancelled_ta_adr['reservation_status_date'], not_cancelled_ta_adr['adr'], label='not cancelled')
plt.plot(cancelled_ta_adr['reservation_status_date'], cancelled_ta_adr['adr'], label='cancelled')
plt.legend()
plt.title('Average Daily Rate',fontsize=30, fontweight='bold', pad=20)
plt.savefig("Average Daily Rate.jpg")
plt.show()
